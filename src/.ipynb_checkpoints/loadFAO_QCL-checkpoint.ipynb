# %%
from neo4j import GraphDatabase
import pandas as pd
import csv
from graph_helpers import graph

# %%
graph_db = graph("bolt://localhost:7687", "neo4j", "asdf")

# %%
datasource = 'FAOSTAT Production: Crops and livestock products'
filepath = '/Users/kassyraymond/PhD/trunk/DatasphereGraph/FAOSTAT/Production_Crops_Livestock_E_All_Data_(Normalized)/'

# %%
el_item_unit_yr = pd.read_csv('%s%s' % (filepath, 'QCL_element_item_unit_yr.csv'))
area_el_yr = pd.read_csv('%s%s' % (filepath, 'QCL_area_element_yr.csv'))
el_yr = pd.read_csv('%s%s' % (filepath, 'QCL_element_yr.csv'))
el_item_area_yr = pd.read_csv('%s%s' % (filepath, 'QCL_item_area_element_year.csv'))

# %%
graph_db.print_datasource(datasource)
# Out:
# FAOSTAT Production: Crops and livestock products
# FAOSTAT Production: Crops and livestock products

# %%
el_yr_cols = el_yr.columns.tolist()
 
for i in range (0, el_yr.shape[0]):
    year = el_yr['Year'].iloc[i]
    source = el_yr['Element'].iloc[i]
    graph_db.print_create_return_table(datasource, source, year)
# Out:
# Laying
# Milk Animals
# Producing Animals/Slaughtered
# Stocks

# %%
for i in range(0, el_item_unit_yr.shape[0]):
    source = el_item_unit_yr['Element'].iloc[i]
    year = el_item_unit_yr['Year'].iloc[i]
    item = el_item_unit_yr['Item'].iloc[i]
    graph_db.print_create_return_category(source, item, year)
# Out:
# Eggs Primary
# Eggs, hen, in shell
# Eggs, other bird, in shell
# Milk, Total
# Milk, whole fresh buffalo
# Milk, whole fresh camel
# Milk, whole fresh cow
# Milk, whole fresh goat
# Milk, whole fresh sheep
# Beef and Buffalo Meat
# Fat, buffaloes
# Fat, camels
# Fat, cattle
# Fat, goats
# Fat, pigs
# Fat, sheep
# Hides, buffalo, fresh
# Hides, cattle, fresh
# Meat nes
# Meat, Poultry
# Meat, ass
# Meat, bird nes
# Meat, buffalo
# Meat, camel
# Meat, cattle
# Meat, chicken
# Meat, duck
# Meat, game
# Meat, goat
# Meat, goose and guinea fowl
# Meat, horse
# Meat, mule
# Meat, other camelids
# Meat, other rodents
# Meat, pig
# Meat, rabbit
# Meat, sheep
# Meat, turkey
# Offals, edible, buffaloes
# Offals, edible, camels
# Offals, edible, cattle
# Offals, edible, goats
# Offals, horses
# Offals, pigs, edible
# Offals, sheep,edible
# Sheep and Goat Meat
# Skins, goat, fresh
# Skins, sheep, fresh
# Asses
# Buffaloes
# Camelids, other
# Camels
# Cattle
# Cattle and Buffaloes
# Chickens
# ...

# %%
#EF_item_area_source_year['source_year'] 
for i in range(0, el_item_area_yr.shape[0]):
    source = el_item_area_yr['Element'].iloc[i]
    if source == 'Producing Animals/Slaughtered'
        year = el_item_area_yr['Year'].iloc[i]
        item = el_item_area_yr['Item'].iloc[i]
        area = el_item_area_yr['Area'].iloc[i]
        graph_db.print_create_return_area(item, area, year, source)
# Out:
# [1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# [1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# ...
