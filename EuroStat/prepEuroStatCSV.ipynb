# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/kassyraymond/PhD/trunk/DatasphereGraph/EuroStat/inFilesCSV/apro_ec_lshen_1_Data.csv')

# %%
df = df[(df['Value'] != ':')]

# %%
df.columns = df.columns.str.lower()

# %%
df.groupby(['ANIMALS'])['TIME'].unique().apply(list).reset_index()
# Out:
#        ANIMALS                                               TIME
# 0  Laying hens  [2003, 2004, 2005, 2006, 2007, 2008, 2009, 201...

# %%
df.groupby(['ANIMALS','GEO'])['TIME'].unique().apply(list).reset_index()
# Out:
#         ANIMALS                                               GEO  \
# 0   Laying hens                                           Austria
# 1   Laying hens                                           Belgium
# 2   Laying hens                                          Bulgaria
# 3   Laying hens                                           Croatia
# 4   Laying hens                                            Cyprus
# 5   Laying hens                                           Czechia
# 6   Laying hens                                           Denmark
# 7   Laying hens                                           Estonia
# 8   Laying hens                                           Finland
# 9   Laying hens                                            France
# 10  Laying hens  Germany (until 1990 former territory of the FRG)
# 11  Laying hens                                            Greece
# 12  Laying hens                                           Hungary
# ...

# %%
df
# Out:
#      TIME                                               GEO      ANIMALS  \
# 1    2003                                           Belgium  Laying hens
# 4    2003                                           Denmark  Laying hens
# 5    2003  Germany (until 1990 former territory of the FRG)  Laying hens
# 7    2003                                           Ireland  Laying hens
# 8    2003                                            Greece  Laying hens
# ..    ...                                               ...          ...
# 226  2010                                           Romania  Laying hens
# 228  2010                                          Slovakia  Laying hens
# 247  2011                                         Lithuania  Laying hens
# 248  2011                                        Luxembourg  Laying hens
# 277  2012                                        Luxembourg  Laying hens
#
#                          UNIT     Value Flag and Footnotes
# ...
